# %%
# %%capture

# !pip install layoutparser

# !pip install "layoutparser[effdet]"

# !pip install "layoutparser[paddledetection]"

# !pip install "layoutparser[ocr]"

# !sudo apt-get install poppler-utils -y

# !pip install layoutparser torchvision && pip install "git+https://github.com/facebookresearch/detectron2.git@v0.5#egg=detectron2"

# %%
# !pip uninstall PIL -y
# !pip uninstall Pillow -y
# !pip install Pillow

# %% [markdown]
# **Load Model**
#
# https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html

# %%
import layoutparser as lp
model = lp.Detectron2LayoutModel(
            config_path ='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config', # In model catalog
            label_map   ={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"}, # In model`label_map`
            extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8] # Optional
        )
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 2
#       1 import layoutparser as lp
# ----> 2 model = lp.Detectron2LayoutModel(
#       3             config_path ='lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config', # In model catalog
#       4             label_map   ={0: "Text", 1: "Title", 2: "List", 3:"Table", 4:"Figure"}, # In model`label_map`
#       5             extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8] # Optional
#       6         )
#
# File c:\Users\TarunKumarChaubey\anaconda3\envs\CVRnD\lib\site-packages\layoutparser\models\detectron2\layoutmodel.py:91, in Detectron2LayoutModel.__init__(self, config_path, model_path, label_map, extra_config, enforce_cpu, device)
#      86     extra_config = []
#      88 config_path, model_path = self.config_parser(
#      89     config_path, model_path, allow_empty_path=True
#      90 )
# ...

# %% [markdown]
# **Load PDF and Split Into Image Page Wise**

# %%
from pdf2image import convert_from_path, convert_from_bytes
images = convert_from_bytes(open('/content/NCERT-Class-12-Chemistry-Part-2.pdf', 'rb').read())

# %%
layout = model.detect(images[23])
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
lp.draw_text(layout, images[23])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7d0f9f7e07f8> in <cell line: 1>()
# ----> 1 lp.draw_text(layout, images[23])
#
# /usr/local/lib/python3.10/dist-packages/layoutparser/visualization.py in wrap(canvas, layout, *args, **kwargs)
#     119         elif isinstance(canvas, np.ndarray):
#     120             canvas = Image.fromarray(canvas)
# --> 121         out = func(canvas, layout, *args, **kwargs)
#     122         return out
#     123
#
# /usr/local/lib/python3.10/dist-packages/layoutparser/visualization.py in draw_text(canvas, layout, arrangement, font_size, font_path, text_color, text_background_color, vertical_text, with_box_on_text, text_box_width, text_box_color, with_layout, **kwargs)
#     328     text_background_color = text_background_color or DEFAULT_TEXT_BACKGROUND
#     329
# ...

# %% [markdown]
# **OCR Agent**

# %%
# !sudo apt update
# !sudo apt install tesseract-ocr
# !sudo apt install libtesseract-dev

# %%
ocr_agent = lp.TesseractAgent(languages='eng')

# %%
ocr_agent.detect(images[8])
# Out:
# '10.1.3 Compounds\nContaining\nsp? C—X\nBond\n\n10.2 llomenclature\n\nCH,CH,CH,Br\n\nThis class includes:\n\n(a) Vinylic halides\nThese are the compounds in which the halogen atom is bonded to\nan sp?-hybridised carbon atom of a carbon-carbon double bond\n\n(C=O. — x\nx CY\n(b) Aryl halides\n\nThese are the compounds in which the halogen atom is bonded to\nthe sp?-hybridised carbon atom of an aromatic ring.\n\nO\n\nHaving learnt the classification of halogenated compounds, let us now\nlearn how these are named. The common names of alkyl halides are\nderived by naming the alkyl group followed by the halide. Alkyl halides\nare named as halosubstituted hydrocarbons in the IUPAC system of\nnomenclature. Haloarenes are the common as well as IUPAC names of\naryl halides. For dihalogen derivatives, the prefixes o-, m-, p- are used in\ncommon system but in IUPAC system, the numerals 1,2; 1,3 and 1,4 are\nused.\n\nH,C-CH-CH, CH,\nLy H,C-CH-CH,Cl\n\nCommon name: n-Propyl bromide Isopropyl chlo
# ...

# %%
lp.draw_text(image, layout, font_size=12, with_box_on_text=True,
             text_box_width=1)
